# %%
import pandas as pd
import math

# %%
df_resultat_20point = pd.read_csv('new_resultat_pour20points.csv', encoding='latin')

# %%
df_resultat_20point["temps_mis_execution"] = df_resultat_20point["temps_mis_execution"] / 1e9
df_resultat_20point.columns =['nb_chemin', 'nombre_de_generation', 'distance', 'temps_mis_execution_en_second']

# %%
min = df_resultat_20point["temps_mis_execution_en_second"].sum()/60
print("Temps total:",math.floor(min),"min",math.floor((min % 1) * 60),"sec")
# Out:
# Temps total: 13 min 41 sec

# %%
df_resultat_20point_moyenne = df_resultat_20point.groupby(["nb_chemin","nombre_de_generation"])[["distance","temps_mis_execution_en_second"]].mean().reset_index()

# %%
df_resultat_20point_moyenne.sort_values("distance")
# Out:
#     nb_chemin  nombre_de_generation      distance  \
# 31        300                  1000   9747.242186
# 30        300                   500   9945.334004
# 27        210                  1000   9991.688323
# 23        150                  1000  10044.841297
# 26        210                   500  10096.347821
# 19        120                  1000  10136.760652
# 22        150                   500  10290.917526
# 18        120                   500  10332.217218
# 15         90                  1000  10380.500802
# 14         90                   500  10503.879147
# 11         60                  1000  10616.671868
# 29        300                   120  10634.880892
# 10         60                   500  10644.667224
# 25        210                   120  10742.836079
# 28        300                    60  11020.265492
# 21        150                   120  11126.605996
# 13         90                   120  11129.344032
# 7          30                  1000  11149.480764
# 24        210                    60  11150.736358
# 17        120                   120  11180.352992
# 9          60                   120  11297.712415
# 6          30                   500  11386.011185
# 20        150                    60  11405.680900
# 12         90                    60  11420.153275
# 3          21                  1000  11545.429653
# 16        120                    60  11569.739658
# 2          21                   500  11835.782514
# 8          60                    60  12122.503155
# 5          30                   120  12183.297806
# 4          30                    60  12656.076935
# 1          21                   120  12721.362637
# 0          21                    60  13262.026937
#
#     temps_mis_execution_en_second
# 31                       3.505963
# 30                       1.868200
# 27                       2.653547
# 23                       1.898565
# 26                       1.332448
# 19                       1.505704
# 22                       0.938659
# 18                       0.752443
# 15                       1.144904
# 14                       0.576153
# 11                       0.752461
# 29                       0.468262
# 10                       0.362598
# 25                       0.318993
# 28                       0.235453
# 21                       0.227995
# 13                       0.149022
# 7                        0.377153
# 24                       0.163220
# 17                       0.184435
# 9                        0.095244
# 6                        0.181995
# 20                       0.113439
# 12                       0.069397
# 3                        0.267357
# 16                       0.092033
# 2                        0.142624
# 8                        0.049853
# 5                        0.042373
# 4                        0.020998
# 1                        0.034428
# 0                        0.018525

# %%
mask_gen_60 = df_resultat_20point["nombre_de_generation"] == 60
mask_gen_120 = df_resultat_20point["nombre_de_generation"] == 120
mask_gen_500 = df_resultat_20point["nombre_de_generation"] == 500
mask_gen_1000 = df_resultat_20point["nombre_de_generation"] == 1000
mask_gen_10000 = df_resultat_20point["nombre_de_generation"] == 10000
mask_gen_20000 = df_resultat_20point["nombre_de_generation"] == 20000

# %%
df_resultat_20point[mask_gen_60].sort_values("distance")
# Out:
#       nb_chemin  nombre_de_generation      distance  \
# 667         120                    60   9761.775111
# 501          90                    60   9838.658007
# 962         210                    60   9966.162413
# 969         210                    60   9981.636969
# 1148        300                    60   9998.582388
# ...         ...                   ...           ...
# 33           21                    60  14006.107743
# 169          30                    60  14016.196537
# 30           21                    60  14017.576673
# 23           21                    60  14230.071756
# 17           21                    60  14787.244746
#
#       temps_mis_execution_en_second
# 667                        0.092535
# 501                        0.068607
# 962                        0.169140
# 969                        0.167617
# 1148                       0.234715
# ...                             ...
# 33                         0.017242
# 169                        0.020464
# 30                         0.016774
# 23                         0.016242
# 17                         0.016719
#
# [320 rows x 4 columns]

# %%
df_resultat_20point[mask_gen_120].sort_values("distance")
# Out:
#       nb_chemin  nombre_de_generation      distance  \
# 845         150                   120   9314.374006
# 1179        300                   120   9552.161102
# 398          60                   120   9624.123259
# 1194        300                   120   9711.659392
# 1021        210                   120   9821.474109
# ...         ...                   ...           ...
# 234          30                   120  13338.223236
# 59           21                   120  13369.404722
# 57           21                   120  13496.238576
# 66           21                   120  13514.874619
# 74           21                   120  13556.518311
#
#       temps_mis_execution_en_second
# 845                        0.222437
# 1179                       0.457798
# 398                        0.091937
# 1194                       0.454264
# 1021                       0.303732
# ...                             ...
# 234                        0.046076
# 59                         0.034956
# 57                         0.036961
# 66                         0.037823
# 74                         0.031772
#
# [320 rows x 4 columns]

# %%
df_resultat_20point[mask_gen_500].sort_values("distance")
# Out:
#       nb_chemin  nombre_de_generation      distance  \
# 1075        210                   500   9189.160394
# 431          60                   500   9202.646011
# 749         120                   500   9281.803914
# 1202        300                   500   9345.307736
# 1217        300                   500   9375.162388
# ...         ...                   ...           ...
# 96           21                   500  12493.163513
# 107          21                   500  12633.450754
# 91           21                   500  12650.983117
# 103          21                   500  12686.982716
# 118          21                   500  12958.699926
#
#       temps_mis_execution_en_second
# 1075                       1.391827
# 431                        0.367373
# 749                        0.744459
# 1202                       1.875067
# 1217                       1.882896
# ...                             ...
# 96                         0.150021
# 107                        0.156500
# 91                         0.158067
# 103                        0.140417
# 118                        0.131915
#
# [320 rows x 4 columns]

# %%
df_resultat_20point[mask_gen_1000].sort_values("distance")
# Out:
#       nb_chemin  nombre_de_generation      distance  \
# 1278        300                  1000   9156.931615
# 933         150                  1000   9162.330053
# 1270        300                  1000   9195.878828
# 1089        210                  1000   9230.699766
# 796         120                  1000   9240.273117
# ...         ...                   ...           ...
# 124          21                  1000  12104.774632
# 155          21                  1000  12112.687146
# 125          21                  1000  12183.990242
# 153          21                  1000  12224.476308
# 144          21                  1000  12297.185522
#
#       temps_mis_execution_en_second
# 1278                       3.460643
# 933                        1.915566
# 1270                       3.701538
# 1089                       2.844725
# 796                        1.471758
# ...                             ...
# 124                        0.266277
# 155                        0.258038
# 125                        0.273330
# 153                        0.262154
# 144                        0.266947
#
# [320 rows x 4 columns]

# %%
df_resultat_20point.describe()
# Out:
#          nb_chemin  nombre_de_generation      distance  \
# count  1280.000000           1280.000000   1280.000000
# mean    122.625000            420.000000  11070.979617
# std      89.299857            375.113222    986.549952
# min      21.000000             60.000000   9156.931615
# 25%      52.500000            105.000000  10310.531439
# 50%     105.000000            310.000000  10953.588484
# 75%     165.000000            625.000000  11684.771579
# max     300.000000           1000.000000  14787.244746
#
#        temps_mis_execution_en_second
# count                    1280.000000
# mean                        0.642014
# std                         0.828096
# min                         0.015462
# 25%                         0.109866
# 50%                         0.254429
# 75%                         0.870634
# max                         4.015483
